# %%
from board_viewer import watch_agent_vs_agent
from challenger.agent import get_move as my_agent
from baselines.minimax.agent import get_move as minimax_agent

watch_agent_vs_agent(my_agent, minimax_agent, pause_seconds=0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from board_viewer import watch_agent_vs_agent
# ----> 2 from challenger.agent import get_move as my_agent
#       3 from baselines.minimax.agent import get_move as minimax_agent
#       4
#       5 watch_agent_vs_agent(my_agent, minimax_agent, pause_seconds=0)
#
# File ~/repos/aichessathon/challenger/agent.py:9
#       7 from chess.polyglot import zobrist_hash
#       8 from collections import Counter
# ----> 9 from ordering import sorted_moves, order_score
#      10 from timing import SearchTimeout, get_budget_ms, check_time, get_deadline
#      11 from evaluation import evaluate
#
# ModuleNotFoundError: No module named 'ordering'
